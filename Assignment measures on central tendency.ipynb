# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt


data = pd.read_csv("C:/Users/DERIC JOSE/Downloads/StudentsPerformance.csv")
data
# Out:
#      gender race/ethnicity parental level of education         lunch  \
# 0    female        group C            some high school  free/reduced
# 1    female        group B                 high school  free/reduced
# 2    female        group B            some high school  free/reduced
# 3    female        group B                some college      standard
# 4    female        group C                some college  free/reduced
# ..      ...            ...                         ...           ...
# 995    male        group E                some college      standard
# 996    male        group A                some college      standard
# 997    male        group D                some college      standard
# 998    male        group E          associate's degree  free/reduced
# 999    male        group E           bachelor's degree      standard
#
#     test preparation course  math score  reading score  writing score
# ...

# %%
m = data['gender'].value_counts()['male']
print('Number of Males:',m)
n = data['gender'].value_counts()['female']
print('Number of Females:',n)
# Out:
# Number of Males: 482
# Number of Females: 518

# %%
data.columns
# Out:
# Index(['gender', 'race/ethnicity', 'parental level of education', 'lunch',
#        'test preparation course', 'math score', 'reading score',
#        'writing score'],
#       dtype='object')

# %% [markdown]
# # What do you think about the students' parental level of education?

# %%
import seaborn as sns

# %%
plt.hist(data["parental level of education"], edgecolor='black', bins=11)
plt.xticks(rotation = 45)
plt.title("Parental level of Education")
plt.show()

# %% [markdown]
# Atleast the parents of the childern in the given dataset been into some high school

# %% [markdown]
# # Who scores the most on average for math, reading and writing based on ● Gender ● Test preparation course

# %%
data.describe()
# Out:
#         math score  reading score  writing score
# count  1000.000000    1000.000000    1000.000000
# mean     66.001000      69.195000      68.119000
# std      15.569567      14.706436      15.226381
# min       0.000000      17.000000      10.000000
# 25%      57.000000      59.000000      58.000000
# 50%      66.000000      70.000000      69.000000
# 75%      77.000000      79.250000      79.000000
# max     100.000000     100.000000     100.000000

# %%
data.mean(axis=0)
# Out:
# C:\Users\DERIC JOSE\AppData\Local\Temp\ipykernel_19164\2773904261.py:1: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   data.mean(axis=0)
# math score       66.001
# reading score    69.195
# writing score    68.119
# dtype: float64

# %%
data[["gender", "math score"]].groupby(["gender", "math score"]).size().reset_index()
# Out:
#      gender  math score  0
# 0    female           0  1
# 1    female           8  1
# 2    female          11  1
# 3    female          13  1
# 4    female          18  1
# ..      ...         ... ..
# 148    male          96  1
# 149    male          97  4
# 150    male          98  2
# 151    male          99  1
# 152    male         100  4
#
# [153 rows x 3 columns]

# %%
df1 = data.groupby(["gender"])[["math score", "reading score", "writing score"]].mean()
df1
# Out:
#         math score  reading score  writing score
# gender
# female   63.376448      72.590734      72.467181
# male     68.821577      65.545643      63.446058

# %%
df2 = data.groupby(["test preparation course"])[["math score", "reading score", "writing score"]].mean()
df2
# Out:
#                          math score  reading score  writing score
# test preparation course
# completed                  69.96648      74.175978      74.684358
# none                       63.78972      66.417445      64.457944

# %% [markdown]
# # What do you think about the scoring variation for math, reading and writing based on ● Gender ● Test preparation course

# %%
## Barplot : Gender vs Math score

sns.barplot(x="gender", y="math score", data=data)
plt.title("Math Score based on Gender")
plt.show()

## Barplot : Gender vs Reading score

sns.barplot(x="gender", y="reading score", data=data)
plt.title("Reading score based on Gender")
plt.show()

## Barplot : Gender vs Math score

sns.barplot(x="gender", y="writing score", data=data)
plt.title("Writing score based on Gender")
plt.show()

# %% [markdown]
# Males scored more marks in maths than females whereas females scored more marks in reading and writing compared to males.

# %%
## Barplot : Test Preparation Score vs Math score

sns.barplot(x="test preparation course", y="math score",  data=data)
plt.title("Math Score")
plt.show()

## Barplot : Test Preparation Score vs Reading score

sns.barplot(x="test preparation course", y="reading score", data=data)
plt.title("Reading scores")
plt.show()

## Barplot : Test Preparation Score vs Math score

sns.barplot(x="test preparation course", y="writing score",  data=data)
plt.title("Writing score")
plt.show()

# %% [markdown]
#  It is very clear that those students who had the status completed for test preparation for the course had scored more marks than those who haven't done any prepation

# %% [markdown]
# # The management needs your help to give bonus points to the top 25% of students based on their math score, so how will you help the management to achieve this.

# %%
data.mean()
# Out:
# C:\Users\DERIC JOSE\AppData\Local\Temp\ipykernel_19164\531903386.py:1: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   data.mean()
# math score       66.001
# reading score    69.195
# writing score    68.119
# dtype: float64

# %%
data["math score"].max()
# Out:
# 100

# %%
data["math score"].min()
# Out:
# 0

# %%
data[data["math score"]>66]
# Out:
#      gender race/ethnicity parental level of education         lunch  \
# 297  female        group B           bachelor's degree      standard
# 298  female        group B            some high school      standard
# 299  female        group B                 high school  free/reduced
# 300  female        group B                 high school  free/reduced
# 301  female        group C           bachelor's degree      standard
# ..      ...            ...                         ...           ...
# 995    male        group E                some college      standard
# 996    male        group A                some college      standard
# 997    male        group D                some college      standard
# 998    male        group E          associate's degree  free/reduced
# 999    male        group E           bachelor's degree      standard
#
#     test preparation course  math score  reading score  writing score
# ...

# %%
top = data["math score"].quantile(.75)

# %%
top
# Out:
# 77.0

# %%
data[data["math score"]>top]
# Out:
#      gender race/ethnicity parental level of education         lunch  \
# 430  female        group A                some college      standard
# 431  female        group B           bachelor's degree  free/reduced
# 432  female        group D           bachelor's degree      standard
# 433  female        group D                 high school      standard
# 434  female        group D           bachelor's degree  free/reduced
# ..      ...            ...                         ...           ...
# 995    male        group E                some college      standard
# 996    male        group A                some college      standard
# 997    male        group D                some college      standard
# 998    male        group E          associate's degree  free/reduced
# 999    male        group E           bachelor's degree      standard
#
#     test preparation course  math score  reading score  writing score
# ...

# %%
data[data["math score"]>top].head(25)
# Out:
#      gender race/ethnicity parental level of education         lunch  \
# 430  female        group A                some college      standard
# 431  female        group B           bachelor's degree  free/reduced
# 432  female        group D           bachelor's degree      standard
# 433  female        group D                 high school      standard
# 434  female        group D           bachelor's degree  free/reduced
# 435  female        group D             master's degree      standard
# 436  female        group B                some college      standard
# 437  female        group C           bachelor's degree      standard
# 438  female        group D                some college      standard
# 439  female        group D           bachelor's degree      standard
# 440  female        group D                some college  free/reduced
# 441  female        group D                some college      standard
# 442  female        group E          associate's degree      standard
# ...

# %%
data[data["math score"]>top].tail(25)
# Out:
#     gender race/ethnicity parental level of education         lunch  \
# 975   male        group C           bachelor's degree      standard
# 976   male        group C             master's degree      standard
# 977   male        group E          associate's degree  free/reduced
# 978   male        group C          associate's degree      standard
# 979   male        group E            some high school      standard
# 980   male        group C                some college      standard
# 981   male        group E                some college  free/reduced
# 982   male        group B            some high school      standard
# 983   male        group C           bachelor's degree      standard
# 984   male        group E            some high school      standard
# 985   male        group E          associate's degree      standard
# 986   male        group E                 high school      standard
# 987   male        group D             master's degree      standard
# ...
