# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df = pd.read_excel('C:/Users/DERIC JOSE/Downloads/iris.xls')
df
# Out:
#   File "C:\Users\DERIC JOSE\AppData\Local\Temp\ipykernel_13484\3737176573.py", line 1
#     df = pd.read_excel('C:\Users\DERIC JOSE\Downloads\iris.xls')
#                                                                ^
# SyntaxError: (unicode error) 'unicodeescape' codec can't decode bytes in position 2-3: truncated \UXXXXXXXX escape

# %% [markdown]
# #### Read the dataset to python environment

# %%
df = pd.read_excel('C:/Users/DERIC JOSE/Downloads/iris.xls')
df
# Out:
#       SL   SW   PL   PW  Classification
# 0    5.1  3.5  1.4  0.2     Iris-setosa
# 1    4.9  3.0  1.4  0.2     Iris-setosa
# 2    4.7  3.2  1.3  0.2     Iris-setosa
# 3    4.6  3.1  1.5  0.2     Iris-setosa
# 4    5.0  3.6  1.4  0.2     Iris-setosa
# ..   ...  ...  ...  ...             ...
# 145  6.7  3.0  5.2  2.3  Iris-virginica
# 146  6.3  2.5  5.0  1.9  Iris-virginica
# 147  6.5  3.0  5.2  2.0  Iris-virginica
# 148  6.2  3.4  5.4  2.3  Iris-virginica
# 149  5.9  3.0  5.1  1.8  Iris-virginica
#
# [150 rows x 5 columns]

# %% [markdown]
# #### Display the columns in the dataset

# %%
df.columns
# Out:
# Index(['SL', 'SW', 'PL', 'PW', 'Classification'], dtype='object')

# %% [markdown]
# #### Calculate the mean of each column of the dataset

# %%
df.mean(numeric_only=True)
# Out:
# SL    5.843333
# SW    3.054000
# PL    3.758667
# PW    1.198667
# dtype: float64

# %% [markdown]
# #### Check for the null values present in the dataset

# %%
df.isnull().sum()
# Out:
# SL                0
# SW                0
# PL                0
# PW                0
# Classification    0
# dtype: int64

# %% [markdown]
# #### Perform meaningful visualizations using the dataset

# %% [markdown]
# ##### Box plot

# %%
plt.figure(figsize = (10,7))
df.boxplot()
# Out:
# <AxesSubplot:>

# %% [markdown]
# ##### Scatter plot

# %%
plt.scatter(df['SL'], df['SW'], df['PL'], df['PW'])
plt.show()

# %% [markdown]
# #####  Histogram

# %%
plt.figure(figsize = (10,7))

plt.hist(df['SL'], bins = 20)
plt.title("Sepal Length")
plt.xlabel("Sepal Length")
plt.ylabel("Count")
plt.show()

# %%
plt.figure(figsize = (10,7))

plt.hist(df['SW'], bins = 20)
plt.title("Sepal Width")
plt.xlabel("Sepal Width")
plt.ylabel("Count")
plt.show()

# %%
plt.figure(figsize = (10,7))

plt.hist(df['PL'], bins = 20)
plt.title("Petal Length")
plt.xlabel("Petal Length")
plt.ylabel("Count")
plt.show()

# %%
plt.figure(figsize = (10,7))

plt.hist(df['PW'], bins = 20)
plt.title("Petal Width")
plt.xlabel("Petal Width")
plt.ylabel("Count")
plt.show()
